# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read csv files

customers= pd.read_csv("../Data/customers.csv")
products = pd.read_csv("../Data/products.csv")
sales = pd.read_csv("../Data/sales.csv")
orders = pd.read_csv("../Data/orders.csv")

# %%
# Visualize the tables

customers.head()
# Out:
#    customer_id        customer_name       gender  age  \
# 0            1        Leanna Busson       Female   30
# 1            2  Zabrina Harrowsmith  Genderfluid   69
# 2            3      Shina Dullaghan   Polygender   59
# 3            4        Hewet McVitie     Bigender   67
# 4            5       Rubia Ashleigh   Polygender   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
products.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47

# %%
sales.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2          212
# 1         1         1         481             118         1          118
# 2         2         1           2              96         3          288
# 3         3         1        1002             106         2          212
# 4         4         1         691             113         3          339

# %%
orders.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
customers.describe()
# Out:
#        customer_id          age     zip_code
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000    49.860000  5004.872000
# std     288.819436    17.647828  2884.497332
# min       1.000000    20.000000     2.000000
# 25%     250.750000    34.000000  2401.750000
# 50%     500.500000    50.000000  5083.000000
# 75%     750.250000    65.000000  7460.250000
# max    1000.000000    80.000000  9998.000000

# %%
products.describe()
# Out:
#         product_id        price     quantity
# count  1260.000000  1260.000000  1260.000000
# mean    629.500000   105.805556    60.150000
# std     363.874979     9.704423    11.670573
# min       0.000000    90.000000    40.000000
# 25%     314.750000    95.750000    50.000000
# 50%     629.500000   108.500000    60.000000
# 75%     944.250000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %%
sales.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %%
orders.describe()
# Out:
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %%
# Merge the dataframes based on their common columns
merged_df = pd.merge(customers, orders, on='customer_id')
merged_df = pd.merge(merged_df, sales, on='order_id')
merged_df = pd.merge(merged_df, products, on='product_id')

# View the first few rows of the merged dataframe
print(merged_df.head())

# Save the merged dataframe to a CSV file
#merged_df.to_csv('merged_data.csv', index=False)
# Out:
#    customer_id  customer_name    gender  age                    home_address  \
# 0            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 1            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 2           81  Lanny Wardale    Female   30     4870 Jackson SummitApt. 538
# 3          258  Mira Heinonen    Female   62     2719 Dietrich KnollApt. 175
# 4          432  Ettie Gonnely  Bigender   34      6172 Andrew AvenueApt. 194
#
#    zip_code            city               state    country  order_id  ...  \
# 0      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 1      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 2      1915  Spencerborough   Western Australia  Australia       863  ...
# 3      1252    South Declan          Queensland  Australia       793  ...
# 4      7029      North Cody            Victoria  Australia       939  ...
#
#    product_id price_per_unit quantity_x  total_price  product_type  \
# 0         211            106          3          318         Shirt
# 1         783             91          2          182        Jacket
# 2         783             91          1           91        Jacket
# 3         783             91          3          273        Jacket
# 4         783             91          2          182        Jacket
#
#    product_name  size  colour price quantity_y
# 0      Chambray     S     red   105         72
# 1      Pullover     L  yellow   114         43
# 2      Pullover     L  yellow   114         43
# 3      Pullover     L  yellow   114         43
# 4      Pullover     L  yellow   114         43
#
# [5 rows x 24 columns]

# %%
merged_df.head()
# Out:
#    customer_id  customer_name    gender  age                    home_address  \
# 0            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 1            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 2           81  Lanny Wardale    Female   30     4870 Jackson SummitApt. 538
# 3          258  Mira Heinonen    Female   62     2719 Dietrich KnollApt. 175
# 4          432  Ettie Gonnely  Bigender   34      6172 Andrew AvenueApt. 194
#
#    zip_code            city               state    country  order_id  ...  \
# 0      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 1      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 2      1915  Spencerborough   Western Australia  Australia       863  ...
# 3      1252    South Declan          Queensland  Australia       793  ...
# 4      7029      North Cody            Victoria  Australia       939  ...
#
#    product_id price_per_unit quantity_x  total_price  product_type  \
# 0         211            106          3          318         Shirt
# 1         783             91          2          182        Jacket
# 2         783             91          1           91        Jacket
# 3         783             91          3          273        Jacket
# 4         783             91          2          182        Jacket
#
#    product_name  size  colour price quantity_y
# 0      Chambray     S     red   105         72
# 1      Pullover     L  yellow   114         43
# 2      Pullover     L  yellow   114         43
# 3      Pullover     L  yellow   114         43
# 4      Pullover     L  yellow   114         43
#
# [5 rows x 24 columns]

# %%
merged_df.describe()
# Out:
#        customer_id          age     zip_code     order_id       payment  \
# count  5000.000000  5000.000000  5000.000000  5000.000000   5000.000000
# mean    504.563000    48.760400  4912.355600   503.038200  33976.785000
# std     276.504896    17.577519  2907.367939   285.964418  14612.706539
# min       1.000000    20.000000    52.000000     1.000000  10043.000000
# 25%     276.000000    34.000000  2273.000000   258.000000  20627.000000
# 50%     509.000000    48.000000  4750.000000   504.500000  34259.000000
# 75%     733.000000    63.000000  7460.250000   749.000000  46608.000000
# max    1000.000000    80.000000  9998.000000   999.000000  59910.000000
#
#           sales_id   product_id  price_per_unit  quantity_x  total_price  \
# count  5000.000000  5000.000000     5000.000000  5000.00000  5000.000000
# mean   2499.500000   634.053200      103.501600     1.99240   206.360000
# std    1443.520003   363.255794        9.195004     0.80751    86.357457
# min       0.000000     1.000000       90.000000     1.00000    90.000000
# 25%    1249.750000   323.000000       95.000000     1.00000   112.000000
# 50%    2499.500000   635.000000      102.000000     2.00000   204.000000
# 75%    3749.250000   951.000000      112.000000     3.00000   285.000000
# max    4999.000000  1259.000000      119.000000     3.00000   357.000000
#
#              price   quantity_y
# count  5000.000000  5000.000000
# mean    105.665400    60.083400
# std       9.735564    11.682523
# min      90.000000    40.000000
# 25%      95.000000    50.000000
# 50%     108.000000    60.000000
# 75%     114.000000    70.000000
# max     119.000000    80.000000

# %%
# What is the distribution of customer ages in the data set?

mean_age = customers['age'].mean()

plt.hist(customers['age'], bins=10, color='blue')
plt.axvline(mean_age, color='red', linestyle='--', linewidth=2, label='Mean Age')
plt.title('Distribution of Customer Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
# What is the range of zip codes in the customer info data set?

min_zip = customers['zip_code'].min()
max_zip = customers['zip_code'].max()

print("Range of zip codes in customer info data set: {}-{}".format(min_zip, max_zip))
# Out:
# Range of zip codes in customer info data set: 2-9998

# %%
# What is the size of the product info data set?

products = pd.read_csv("../Data/products.csv")
print("Size of products data set: ", products.shape[0])
# Out:
# Size of products data set:  1260

# %%
# What is the average price of the products in the product info data set?

products = pd.read_csv("../Data/products.csv")

average_price = products['price'].mean()
print("Average price of products in products data set: ${:.2f}".format(average_price))
# Out:
# Average price of products in products data set: $105.81

# %%
# What is the size of the sales data set?

sales = pd.read_csv("../Data/sales.csv")
print("Size of sales data set: ", sales.shape[0])
# Out:
# Size of sales data set:  5000

# %%
# What is the range of order dates in the sales data set?

orders = pd.read_csv("../Data/orders.csv")

min_date = orders['order_date'].min()
max_date = orders['order_date'].max()

print("Range of order dates in sales data set: {}-{}".format(min_date, max_date))
# Out:
# Range of order dates in sales data set: 2021-1-1-2021-9-9

# %%
# What is the distribution of delivery times in the sales data set?

# Calculate delivery times and days
delivery_times = pd.to_datetime(orders['delivery_date']) - pd.to_datetime(orders['order_date'])
delivery_days = delivery_times.dt.days

# Calculate mean delivery time
mean_delivery_time = delivery_days.mean()

# Plot the histogram with vertical line for mean delivery time
plt.hist(delivery_days, bins=10, color='#4c72b0', alpha=0.8)
plt.axvline(mean_delivery_time, color='red', linestyle='--', linewidth=2, label='Mean Delivery Time')
plt.title('Distribution of Delivery Times')
plt.xlabel('Days')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
# What is the range of prices per unit in the sales data set?

min_price = sales['price_per_unit'].min()
max_price = sales['price_per_unit'].max()

print("Range of prices per unit in sales data set: ${:.2f}-${:.2f}".format(min_price, max_price))
# Out:
# Range of prices per unit in sales data set: $90.00-$119.00

# %%
# What is the range of quantities sold in the sales data set?

min_quantity = sales['quantity'].min()
max_quantity = sales['quantity'].max()

print("Range of quantities sold in sales data set: {}-{}".format(min_quantity, max_quantity))
# Out:
# Range of quantities sold in sales data set: 1-3

# %%
# What is the average quantity of products sold per order in the sales data set?

avg_quantity = sales['quantity'].mean()
print("Average quantity of products sold per order: {:.2f}".format(avg_quantity))
# Out:
# Average quantity of products sold per order: 1.99

# %%
# What is the total revenue generated by the sales data set?

total_revenue = sales['total_price'].sum()
print("Total revenue generated by the sales data set: ${:.2f}".format(total_revenue))
# Out:
# Total revenue generated by the sales data set: $1031800.00

# %%
# What is the most common product type in the product info data set?

most_common_product_type = products['product_type'].mode()[0]
print("Most common product type in the product info data set: ", most_common_product_type)
# Out:
# Most common product type in the product info data set:  Jacket

# %%
# What is the distribution of product prices in the product info data set?

# Plot the histogram with density curve and orange color scheme
plt.hist(products['price'], bins=10, density=True, color='#ff9f00', alpha=0.8)
plt.grid(True, axis='y', alpha=0.5, linestyle='--')
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Density')
plt.show()

# %%
# Gender and age description

gender_grouped = customers.groupby('gender')
gender_counts = gender_grouped.size()
gender_ages = gender_grouped['age'].mean()

print(gender_counts)
print(gender_ages)
# Out:
# gender
# Agender        114
# Bigender       120
# Female         115
# Genderfluid    122
# Genderqueer    127
# Male           143
# Non-binary     131
# Polygender     128
# dtype: int64
# gender
# Agender        47.649123
# Bigender       51.025000
# Female         49.147826
# Genderfluid    47.803279
# Genderqueer    49.984252
# Male           51.230769
# Non-binary     51.778626
# Polygender     49.718750
# Name: age, dtype: float64

# %%
# Gender and age description

gender_grouped = customers.groupby('gender')
gender_counts = gender_grouped.size()
gender_ages = gender_grouped['age'].mean()

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
axs[0].set_title('Number of Customers by Gender', fontsize=14)

axs[1].pie(gender_ages.values, labels=gender_ages.index, autopct='%1.1f%%', startangle=90)
axs[1].set_title('Average Age by Gender', fontsize=14)

plt.subplots_adjust(wspace=0.3)
plt.show()

# %%
# Count number of customers in each country
country_counts = customers.groupby('country').size().sort_values(ascending=False)

# Calculate average age for customers in each country
country_ages = customers.groupby('country')['age'].mean().sort_values(ascending=False)

# Calculate percentage of male and female customers in each country
gender_pct_by_country = pd.crosstab(index=customers['country'], columns=customers['gender'], normalize='index') * 100

print("Number of Customers by Country:")
print(country_counts)
print("\nAverage Age of Customers by Country:")
print(country_ages)
print("\nPercentage of Male and Female Customers by Country:")
print(gender_pct_by_country)
# Out:
# Number of Customers by Country:
# country
# Australia    1000
# dtype: int64
#
# Average Age of Customers by Country:
# country
# Australia    49.86
# Name: age, dtype: float64
#
# Percentage of Male and Female Customers by Country:
# gender     Agender  Bigender  Female  Genderfluid  Genderqueer  Male  \
# country
# Australia     11.4      12.0    11.5         12.2         12.7  14.3
#
# gender     Non-binary  Polygender
# country
# Australia        13.1        12.8

# %%
# Count number of customers in each country
country_counts = customers.groupby('country').size().sort_values(ascending=False)

# Calculate average age for customers in each country
country_ages = customers.groupby('country')['age'].mean().sort_values(ascending=False)

# Calculate percentage of male and female customers in each country
gender_pct_by_country = pd.crosstab(index=customers['country'], columns=customers['gender'], normalize='index') * 100

# Distribution of customers by state
state_counts = customers.groupby('state').size().sort_values(ascending=False)
plt.figure(figsize=(10,5))
plt.bar(state_counts.index, state_counts.values, color='blue')
plt.title('Distribution of Customers by State')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Distribution of customers by city
city_counts = customers.groupby('city').size().sort_values(ascending=False)[:10]
plt.figure(figsize=(10,5))
plt.bar(city_counts.index, city_counts.values, color='green')
plt.title('Distribution of Customers by City (Top 10)')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

print("Number of Customers by Country:")
print(country_counts)
print("\nAverage Age of Customers by Country:")
print(country_ages)
print("\nPercentage of Male and Female Customers by Country:")
print(gender_pct_by_country)
# Out:
# Number of Customers by Country:
# country
# Australia    1000
# dtype: int64
#
# Average Age of Customers by Country:
# country
# Australia    49.86
# Name: age, dtype: float64
#
# Percentage of Male and Female Customers by Country:
# gender     Agender  Bigender  Female  Genderfluid  Genderqueer  Male  \
# country
# Australia     11.4      12.0    11.5         12.2         12.7  14.3
#
# gender     Non-binary  Polygender
# country
# Australia        13.1        12.8

# %%
import matplotlib.pyplot as plt

# group customers by state and gender, and count the number of occurrences
state_gender_counts = customers.groupby(['state', 'gender'])['customer_id'].count().reset_index()
state_gender_counts.columns = ['state', 'gender', 'count']

# plot the bar chart
fig, ax = plt.subplots(figsize=(12, 6))
for i, g in enumerate(['Female', 'Male', 'Other']):
    gender_counts = state_gender_counts[state_gender_counts['gender'] == g]
    ax.bar(gender_counts['state'], gender_counts['count'], label=g, alpha=0.8, color=['#F15B40', '#4A90E2', '#60BD68'][i])

# add labels and legend
ax.set_xlabel('State')
ax.set_ylabel('Count')
ax.set_title('Distribution of Gender by State')
ax.legend()

plt.show()

# %%
# plot the boxplot
fig, ax = plt.subplots(figsize=(12, 6))
sns.boxplot(x='state', y='age', data=customers, ax=ax, color='#4A90E2')
sns.stripplot(x='state', y='age', data=customers, ax=ax, color='grey', alpha=0.5)

# add labels and title
ax.set_xlabel('State')
ax.set_ylabel('Age')
ax.set_title('Distribution of Age by State')

plt.show()

# %%
# Products Data


# Display the first 5 rows of the data set
print(products.head())

# Get basic statistics of the numerical variables
print(products.describe())

# Get the counts of each product type
product_type_counts = products['product_type'].value_counts()
print(product_type_counts)

# Plot the distribution of product prices
plt.hist(products['price'], bins=10, color='orange')
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# Get the counts of each product size
product_size_counts = products['size'].value_counts()
print(product_size_counts)

# Get the counts of each product color
product_color_counts = products['colour'].value_counts()
print(product_color_counts)

# Plot the distribution of product quantities
plt.hist(products['quantity'], bins=10, color='blue')
plt.title('Distribution of Product Quantities')
plt.xlabel('Quantity')
plt.ylabel('Count')
plt.show()
# Out:
#    product_id product_type  product_name size colour  price  quantity
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#         product_id        price     quantity
# count  1260.000000  1260.000000  1260.000000
# mean    629.500000   105.805556    60.150000
# std     363.874979     9.704423    11.670573
# min       0.000000    90.000000    40.000000
# 25%     314.750000    95.750000    50.000000
# 50%     629.500000   108.500000    60.000000
# 75%     944.250000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000
# Shirt       420
# Jacket      420
# Trousers    420
# Name: product_type, dtype: int64
# XS    252
# S     252
# M     252
# L     252
# XL    252
# Name: size, dtype: int64
# red       180
# orange    180
# yellow    180
# green     180
# blue      180
# indigo    180
# violet    180
# Name: colour, dtype: int64

# %%
# Get the counts of each product type
product_type_counts = products['product_type'].value_counts()

# Plot the counts of each product type in a bar chart
plt.bar(product_type_counts.index, product_type_counts.values, color='orange')
plt.title('Distribution of Product Types')
plt.xlabel('Product Type')
plt.ylabel('Count')
plt.show()

# %%
# Generate descriptive statistics for numerical variables in sales

sales_stats = sales[['price_per_unit', 'quantity', 'total_price']].describe()

print(sales_stats)
# Out:
#        price_per_unit    quantity  total_price
# count     5000.000000  5000.00000  5000.000000
# mean       103.501600     1.99240   206.360000
# std          9.195004     0.80751    86.357457
# min         90.000000     1.00000    90.000000
# 25%         95.000000     1.00000   112.000000
# 50%        102.000000     2.00000   204.000000
# 75%        112.000000     3.00000   285.000000
# max        119.000000     3.00000   357.000000

# %%
# Merge the sales and orders data to get the date information
sales_orders = pd.merge(sales, orders, on='order_id')

# Convert the order_date column to a pandas datetime object
sales_orders['order_date'] = pd.to_datetime(sales_orders['order_date'])

# Add a new column to the sales_orders dataframe for the month of the order
sales_orders['month'] = sales_orders['order_date'].dt.strftime('%Y-%m')

# Group the sales data by month and sum the total_price column
monthly_sales = sales_orders.groupby('month')['total_price'].sum()

# Create a line graph of the monthly sales data
plt.plot(monthly_sales.index, monthly_sales.values)
plt.xlabel('Month')
plt.xticks(rotation=90)  # Rotate the x-axis labels by 90 degrees
plt.ylabel('Sales')
plt.title('Sales Trends Over Months')
plt.show()

# %%
plt.plot(monthly_sales.index, monthly_sales.values, label='Monthly Sales')
plt.xlabel('Month')
plt.xticks(rotation=90)
plt.ylabel('Sales')
plt.title('Sales Trends Over Months')
plt.grid(True)
plt.legend()  # Add a legend to the plot
plt.show()

# %%
# Merge the sales and orders data to get the date information
sales_orders = pd.merge(sales, orders, on='order_id')

# Convert the order_date column to a pandas datetime object
sales_orders['order_date'] = pd.to_datetime(sales_orders['order_date'])

# Add a new column to the sales_orders dataframe for the month of the order
sales_orders['month'] = sales_orders['order_date'].dt.strftime('%Y-%m')

# Group the sales data by month and sum the total_price column
monthly_sales = sales_orders.groupby('month')['total_price'].sum()

# Find the month with the highest and lowest sales
highest_sales_month = monthly_sales.idxmax()
lowest_sales_month = monthly_sales.idxmin()

# Create a line graph of the monthly sales data
plt.plot(monthly_sales.index, monthly_sales.values, label='Monthly Sales', color='blue', linestyle='--')
plt.xlabel('Month', fontsize=14)
plt.xticks(rotation=90, fontsize=12)
plt.ylabel('Sales', fontsize=14)
plt.title('Sales Trends Over Months', fontsize=16)
plt.grid(True)
plt.legend()

# Print information about the highest and lowest sales months
print(f"The month with the highest sales was {highest_sales_month} with a total of ${monthly_sales[highest_sales_month]:,.2f}")
print(f"The month with the lowest sales was {lowest_sales_month} with a total of ${monthly_sales[lowest_sales_month]:,.2f}")

plt.show()
# Out:
# The month with the highest sales was 2021-03 with a total of $131,364.00
# The month with the lowest sales was 2021-10 with a total of $84,266.00
