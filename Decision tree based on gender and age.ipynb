# %% [markdown]
# # Creating a decision tree

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
#Read CSV file
sales = pd.read_csv("..\Python\customer_order_product.csv")
sales
# Out:
#      customer_id_x        customer_name       gender  age  \
# 0                1        Leanna Busson       Female   30
# 1                2  Zabrina Harrowsmith  Genderfluid   69
# 2                3      Shina Dullaghan   Polygender   59
# 3                4        Hewet McVitie     Bigender   67
# 4                5       Rubia Ashleigh   Polygender   30
# ..             ...                  ...          ...  ...
# 995            996       Elvira Sarfati      Agender   59
# 996            997       Dickie Grushin   Non-binary   30
# 997            998       Rebecka Fabler   Polygender   32
# 998            999       Carita Vynarde   Polygender   30
# 999           1000     Mandel Fairbanks         Male   71
#
#                        home_address  zip_code                city  \
# 0    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1        8327 Kirlin SummitApt. 461      8223     New Zacharyfort
# 2         269 Gemma SummitSuite 109      5661            Aliburgh
# 3         743 Bailey GroveSuite 141      1729   South Justinhaven
# 4           48 Hyatt ManorSuite 375      4032      Griffithsshire
# ..                              ...       ...                 ...
# 995    0433 Armstrong HillSuite 974      7613     Lake Danielland
# 996         04 Howell PassSuite 209      6950         Ellaborough
# 997       72 Annabelle PassApt. 446        52          Kohlerberg
# 998       170 Wilson AvenueApt. 577      7849      East Oscarfurt
# 999      1671 Lauren KnollSuite 945      9012  Lake Audreyborough
#
#                             state    country  order_id  ...  product_type  \
# 0              Northern Territory  Australia         1  ...         Shirt
# 1                 South Australia  Australia         2  ...         Shirt
# 2    Australian Capital Territory  Australia         3  ...         Shirt
# 3                      Queensland  Australia         4  ...         Shirt
# 4                      Queensland  Australia         5  ...         Shirt
# ..                            ...        ...       ...  ...           ...
# 995                      Tasmania  Australia       996  ...      Trousers
# 996                      Tasmania  Australia       997  ...      Trousers
# 997                    Queensland  Australia       998  ...      Trousers
# 998             Western Australia  Australia       999  ...      Trousers
# 999                      Tasmania  Australia      1000  ...      Trousers
#
#      product_name size colour  price quantity sales year_order month_order  \
# 0    Oxford Cloth   XS    red    114       66  7524       2021           8
# 1    Oxford Cloth    S    red    114       53  6042       2021           2
# 2    Oxford Cloth    M    red    114       54  6156       2021          10
# 3    Oxford Cloth    L    red    114       69  7866       2021           5
# 4    Oxford Cloth   XL    red    114       47  5358       2021           3
# ..            ...  ...    ...    ...      ...   ...        ...         ...
# 995          Wool   XS  green    111       73  8103       2021           1
# 996          Wool    S  green    111       43  4773       2021           1
# 997          Wool    M  green    111       41  4551       2021           5
# 998          Wool    L  green    111       42  4662       2021           6
# 999          Wool   XL  green    111       48  5328       2021           4
#
#      day_order
# 0           30
# 1            3
# 2            8
# 3            6
# 4           23
# ..         ...
# 995         13
# 996         18
# 997          5
# 998         15
# 999          7
#
# [1000 rows x 25 columns]

# %%
# create a dictionary of replacement values
replace_dict = {'Non-binary': 'Other', 'Polygender': 'Other', 'Agender':'Other', 'Bigender':'Other', 'Genderfluid':'Other', 'Genderqueer':'Other'}
# use replace() with the dictionary to perform the replacements
sales['gender'] = sales['gender'].replace(replace_dict)
# display the updated DataFrame
print("Updated DataFrame:")
print(sales)
# Out:
# Updated DataFrame:
#      customer_id_x        customer_name  gender  age  \
# 0                1        Leanna Busson  Female   30
# 1                2  Zabrina Harrowsmith   Other   69
# 2                3      Shina Dullaghan   Other   59
# 3                4        Hewet McVitie   Other   67
# 4                5       Rubia Ashleigh   Other   30
# ..             ...                  ...     ...  ...
# 995            996       Elvira Sarfati   Other   59
# 996            997       Dickie Grushin   Other   30
# 997            998       Rebecka Fabler   Other   32
# 998            999       Carita Vynarde   Other   30
# 999           1000     Mandel Fairbanks    Male   71
#
#                        home_address  zip_code                city  \
# 0    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1        8327 Kirlin SummitApt. 461      8223     New Zacharyfort
# 2         269 Gemma SummitSuite 109      5661            Aliburgh
# 3         743 Bailey GroveSuite 141      1729   South Justinhaven
# 4           48 Hyatt ManorSuite 375      4032      Griffithsshire
# ..                              ...       ...                 ...
# 995    0433 Armstrong HillSuite 974      7613     Lake Danielland
# 996         04 Howell PassSuite 209      6950         Ellaborough
# 997       72 Annabelle PassApt. 446        52          Kohlerberg
# 998       170 Wilson AvenueApt. 577      7849      East Oscarfurt
# 999      1671 Lauren KnollSuite 945      9012  Lake Audreyborough
#
#                             state    country  order_id  ...  product_type  \
# 0              Northern Territory  Australia         1  ...         Shirt
# 1                 South Australia  Australia         2  ...         Shirt
# 2    Australian Capital Territory  Australia         3  ...         Shirt
# 3                      Queensland  Australia         4  ...         Shirt
# 4                      Queensland  Australia         5  ...         Shirt
# ..                            ...        ...       ...  ...           ...
# 995                      Tasmania  Australia       996  ...      Trousers
# 996                      Tasmania  Australia       997  ...      Trousers
# 997                    Queensland  Australia       998  ...      Trousers
# 998             Western Australia  Australia       999  ...      Trousers
# 999                      Tasmania  Australia      1000  ...      Trousers
#
#      product_name size colour  price quantity sales year_order month_order  \
# 0    Oxford Cloth   XS    red    114       66  7524       2021           8
# 1    Oxford Cloth    S    red    114       53  6042       2021           2
# 2    Oxford Cloth    M    red    114       54  6156       2021          10
# 3    Oxford Cloth    L    red    114       69  7866       2021           5
# 4    Oxford Cloth   XL    red    114       47  5358       2021           3
# ..            ...  ...    ...    ...      ...   ...        ...         ...
# 995          Wool   XS  green    111       73  8103       2021           1
# 996          Wool    S  green    111       43  4773       2021           1
# 997          Wool    M  green    111       41  4551       2021           5
# 998          Wool    L  green    111       42  4662       2021           6
# 999          Wool   XL  green    111       48  5328       2021           4
#
#      day_order
# 0           30
# 1            3
# 2            8
# 3            6
# 4           23
# ..         ...
# 995         13
# 996         18
# 997          5
# 998         15
# 999          7
#
# [1000 rows x 25 columns]

# %%
# Use factorize to assign a unique integer to each unique value in the 'Gender' column
sales['gender'] = pd.factorize(sales['gender'])[0]

print(sales)
# Out:
#      customer_id_x        customer_name  gender  age  \
# 0                1        Leanna Busson       0   30
# 1                2  Zabrina Harrowsmith       1   69
# 2                3      Shina Dullaghan       1   59
# 3                4        Hewet McVitie       1   67
# 4                5       Rubia Ashleigh       1   30
# ..             ...                  ...     ...  ...
# 995            996       Elvira Sarfati       1   59
# 996            997       Dickie Grushin       1   30
# 997            998       Rebecka Fabler       1   32
# 998            999       Carita Vynarde       1   30
# 999           1000     Mandel Fairbanks       2   71
#
#                        home_address  zip_code                city  \
# 0    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1        8327 Kirlin SummitApt. 461      8223     New Zacharyfort
# 2         269 Gemma SummitSuite 109      5661            Aliburgh
# 3         743 Bailey GroveSuite 141      1729   South Justinhaven
# 4           48 Hyatt ManorSuite 375      4032      Griffithsshire
# ..                              ...       ...                 ...
# 995    0433 Armstrong HillSuite 974      7613     Lake Danielland
# 996         04 Howell PassSuite 209      6950         Ellaborough
# 997       72 Annabelle PassApt. 446        52          Kohlerberg
# 998       170 Wilson AvenueApt. 577      7849      East Oscarfurt
# 999      1671 Lauren KnollSuite 945      9012  Lake Audreyborough
#
#                             state    country  order_id  ...  product_type  \
# 0              Northern Territory  Australia         1  ...         Shirt
# 1                 South Australia  Australia         2  ...         Shirt
# 2    Australian Capital Territory  Australia         3  ...         Shirt
# 3                      Queensland  Australia         4  ...         Shirt
# 4                      Queensland  Australia         5  ...         Shirt
# ..                            ...        ...       ...  ...           ...
# 995                      Tasmania  Australia       996  ...      Trousers
# 996                      Tasmania  Australia       997  ...      Trousers
# 997                    Queensland  Australia       998  ...      Trousers
# 998             Western Australia  Australia       999  ...      Trousers
# 999                      Tasmania  Australia      1000  ...      Trousers
#
#      product_name size colour  price quantity sales year_order month_order  \
# 0    Oxford Cloth   XS    red    114       66  7524       2021           8
# 1    Oxford Cloth    S    red    114       53  6042       2021           2
# 2    Oxford Cloth    M    red    114       54  6156       2021          10
# 3    Oxford Cloth    L    red    114       69  7866       2021           5
# 4    Oxford Cloth   XL    red    114       47  5358       2021           3
# ..            ...  ...    ...    ...      ...   ...        ...         ...
# 995          Wool   XS  green    111       73  8103       2021           1
# 996          Wool    S  green    111       43  4773       2021           1
# 997          Wool    M  green    111       41  4551       2021           5
# 998          Wool    L  green    111       42  4662       2021           6
# 999          Wool   XL  green    111       48  5328       2021           4
#
#      day_order
# 0           30
# 1            3
# 2            8
# 3            6
# 4           23
# ..         ...
# 995         13
# 996         18
# 997          5
# 998         15
# 999          7
#
# [1000 rows x 25 columns]

# %%
#Create input set
X = sales.drop(columns=['customer_id_x','customer_name', 'home_address', 'zip_code', 'city', 'state', 'country', 'order_id', 'product_type', 'product_name', 'size','colour', 'price', 'quantity', 'sales', 'year_order', 'month_order', 'day_order', 'customer_id_y', 'payment','order_date', 'delivery_date', 'product_id'])
X
# Out:
#      gender  age
# 0         0   30
# 1         1   69
# 2         1   59
# 3         1   67
# 4         1   30
# ..      ...  ...
# 995       1   59
# 996       1   30
# 997       1   32
# 998       1   30
# 999       2   71
#
# [1000 rows x 2 columns]

# %%
#Create output set
y = sales['product_type']
y
# Out:
# 0         Shirt
# 1         Shirt
# 2         Shirt
# 3         Shirt
# 4         Shirt
#          ...
# 995    Trousers
# 996    Trousers
# 997    Trousers
# 998    Trousers
# 999    Trousers
# Name: product_type, Length: 1000, dtype: object

# %%
# Measure accuracy of the model
# Split dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Create, train the model and make a prediction
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
#[ [3, 80] , [8, 71]]

score = accuracy_score(y_test, predictions)
score
# Out:
# 0.38

# %%
tree.export_graphviz(model, out_file='product-recommender.dot',
                    feature_names=['age', 'gender'],
                    class_names=sorted(y.unique()),
                    label='all',
                    rounded=True,
                    filled=True)

# %%
#The acuracy would be higher if we would have more data
